# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Text Classification Assessment
#
# ### Goal: Given a set of text movie reviews that have been labeled negative or positive
#
# For more information on this dataset visit http://ai.stanford.edu/~amaas/data/sentiment/
#
# ## Complete the tasks in bold below!

# %% [markdown]
# **Task: Perform imports and load the dataset into a pandas DataFrame**
# For this exercise you can load the dataset from `'../DATA/moviereviews.csv'`.

# %%
# CODE HERE

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../DATA/moviereviews.csv')

# %%
df.head()
# Out:
#   label                                             review
# 0   neg  how do films like mouse hunt get into theatres...
# 1   neg  some talented actresses are blessed with a dem...
# 2   pos  this has been an extraordinary year for austra...
# 3   pos  according to hollywood movies made in last few...
# 4   neg  my first press screening of 1998 and already i...

# %% [markdown]
# **TASK: Check to see if there are any missing values in the dataframe.**

# %%
#CODE HERE
df.isna().sum()
# Out:
# label     0
# review    0
# dtype: int64

# %%
# Out:
# label      0
# review    35
# dtype: int64

# %% [markdown]
# **TASK: Remove any reviews that are NaN**

# %%
df = df.dropna(axis=0)

# %% [markdown]
# **TASK: Check to see if any reviews are blank strings and not just NaN. Note: This means a review text could just be: "" or "  " or some other larger blank string. How would you check for this? Note: There are many ways! Once you've discovered the reviews that are blank strings, go ahead and remove them as well. [Click me for a big hint](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.isspace.html)**

# %%
df[df['review'].str.isspace()]
# Out:
# Empty DataFrame
# Columns: [label, review]
# Index: []

# %%
# Out:
# 27

# %%
# Out:
#      label review
# 57     neg
# 71     pos
# 147    pos
# 151    pos
# 283    pos
# 307    pos
# 313    neg
# 323    pos
# 343    pos
# 351    neg
# 427    pos
# 501    neg
# 633    pos
# 675    neg
# 815    neg
# 851    neg
# 977    neg
# 1079   neg
# 1299   pos
# 1455   neg
# 1493   pos
# 1525   neg
# 1531   neg
# 1763   neg
# 1851   neg
# 1905   pos
# 1993   pos

# %%
df.drop(df[df['review'].str.isspace()].index,inplace=True)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1938 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1938 non-null   object
#  1   review  1938 non-null   object
# dtypes: object(2)
# memory usage: 45.4+ KB

# %% [markdown]
# **TASK: Confirm the value counts per label:**

# %%
#CODE HERE
df['label'].value_counts()
# Out:
# neg    969
# pos    969
# Name: label, dtype: int64

# %%
# Out:
# pos    969
# neg    969
# Name: label, dtype: int64

# %% [markdown]
# ## EDA on Bag of Words
#
# **Bonus Task: Can you figure out how to use a CountVectorizer model to get the top 20 words (that are not english stop words) per label type? Note, this is a bonus task as we did not show this in the lectures. But a quick cursory Google search should put you on the right path.  [Click me for a big hint](https://stackoverflow.com/questions/16288497/find-the-most-common-term-in-scikit-learn-classifier)**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
#CODE HERE
vec = CountVectorizer(stop_words='english').fit(df['review'])
bag_of_words = vec.transform(df['review'])
sum_words = bag_of_words.sum(axis=0)

# %%
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
sorted(words_freq, key=lambda x: x[1], reverse=True)
# Out:
# [('film', 9065),
#  ('movie', 5520),
#  ('like', 3529),
#  ('just', 2753),
#  ('good', 2310),
#  ('time', 2302),
#  ('story', 2107),
#  ('character', 1963),
#  ('characters', 1795),
#  ('way', 1598),
#  ('make', 1577),
#  ('life', 1536),
#  ('does', 1494),
#  ('films', 1474),
#  ('really', 1474),
#  ('plot', 1465),
#  ('little', 1447),
#  ('people', 1397),
#  ('bad', 1336),
#  ('man', 1335),
#  ('scene', 1309),
#  ('best', 1285),
#  ('new', 1255),
#  ('don', 1238),
#  ('doesn', 1224),
#  ('scenes', 1212),
#  ('director', 1191),
#  ('movies', 1148),
#  ('know', 1146),
#  ('action', 1136),
#  ('great', 1071),
#  ('love', 1071),
#  ('big', 1031),
#  ('end', 1015),
#  ('work', 993),
#  ('world', 987),
#  ('makes', 958),
#  ('audience', 893),
#  ('better', 891),
#  ('real', 866),
#  ('seen', 861),
#  ('role', 852),
#  ('performance', 849),
#  ('going', 848),
#  ('year', 840),
#  ('old', 835),
#  ('isn', 834),
#  ('gets', 834),
#  ('funny', 822),
#  ('years', 819),
#  ('comedy', 819),
# ...

# %%
neg_vec = CountVectorizer(stop_words='english').fit(df[df['label']=='neg']['review'])
bag_of_words = neg_vec.transform(df[df['label']=='neg']['review'])
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in neg_vec.vocabulary_.items()]
print('Top 20 words for negative reviews were')
print(sorted(words_freq, key=lambda x: x[1], reverse=True)[:21])
# Out:
# Top 20 words for negative reviews were
# [('film', 4063), ('movie', 3131), ('like', 1808), ('just', 1480), ('time', 1127), ('good', 1117), ('bad', 997), ('character', 926), ('story', 908), ('plot', 888), ('characters', 838), ('make', 813), ('really', 743), ('way', 734), ('little', 696), ('don', 683), ('does', 666), ('doesn', 648), ('action', 635), ('scene', 634), ('people', 628)]

# %%
pos_vec = CountVectorizer(stop_words='english').fit(df[df['label']=='pos']['review'])
bag_of_words = pos_vec.transform(df[df['label']=='pos']['review'])
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in pos_vec.vocabulary_.items()]
print('Top 20 words for positive reviews were')
print(sorted(words_freq, key=lambda x: x[1], reverse=True)[:21])
# Out:
# Top 20 words for positive reviews were
# [('film', 5002), ('movie', 2389), ('like', 1721), ('just', 1273), ('story', 1199), ('good', 1193), ('time', 1175), ('character', 1037), ('life', 1032), ('characters', 957), ('way', 864), ('films', 851), ('does', 828), ('best', 788), ('people', 769), ('make', 764), ('little', 751), ('really', 731), ('man', 728), ('new', 702), ('great', 692)]

# %%
# Out:
# Top 20 words used for Negative reviews.
# [('film', 4063), ('movie', 3131), ('like', 1808), ('just', 1480), ('time', 1127), ('good', 1117), ('bad', 997), ('character', 926), ('story', 908), ('plot', 888), ('characters', 838), ('make', 813), ('really', 743), ('way', 734), ('little', 696), ('don', 683), ('does', 666), ('doesn', 648), ('action', 635), ('scene', 634)]

# %%
# Out:
# Top 20 words used for Positive reviews.
# [('film', 5002), ('movie', 2389), ('like', 1721), ('just', 1273), ('story', 1199), ('good', 1193), ('time', 1175), ('character', 1037), ('life', 1032), ('characters', 957), ('way', 864), ('films', 851), ('does', 828), ('best', 788), ('people', 769), ('make', 764), ('little', 751), ('really', 731), ('man', 728), ('new', 702)]

# %% [markdown]
# ### Training and Data
#
# **TASK: Split the data into features and a label (X and y) and then preform a train/test split. You may use whatever settings you like. To compare your results to the solution notebook, use `test_size=0.20, random_state=101`**

# %%
from sklearn.model_selection import train_test_split

# %%
#CODE HERE
X = df['review']
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# ### Training a Mode
#
# **TASK: Create a PipeLine that will both create a TF-IDF Vector out of the raw text data and fit a supervised learning model of your choice. Then fit that pipeline on the training data.**

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# %%
#CODE HERE
pipe = Pipeline([('tfidf',TfidfVectorizer()),('svc',LinearSVC())])
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('svc', LinearSVC())])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('svc', LinearSVC())])

# %%
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('svc', LinearSVC())])

# %% [markdown]
# **TASK: Create a classification report and plot a confusion matrix based on the results of your PipeLine.**

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
#CODE HERE
y_pred = pipe.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.81      0.86      0.83       191
#          pos       0.85      0.81      0.83       197
#
#     accuracy                           0.83       388
#    macro avg       0.83      0.83      0.83       388
# weighted avg       0.83      0.83      0.83       388

# %%
plot_confusion_matrix(pipe, X_test, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.81      0.86      0.83       191
#          pos       0.85      0.81      0.83       197
#
#     accuracy                           0.83       388
#    macro avg       0.83      0.83      0.83       388
# weighted avg       0.83      0.83      0.83       388

# %% [markdown]
# ## Great job!
